# %% [markdown]
# # ASSIGNMENT 4 :- Function With Loops

# %% [markdown]
# ## Problem 1: Mobile Recharge Validation System

# %% [markdown]
# - Problem Statement
# - Create a function to validate a mobile recharge request.
# - Rules:
# - Recharge amount must be ≥ ₹50
# - Valid plans: 199, 299, 399, 599
# - User should be allowed to retry if invalid
# - Real-Time Use
# - Telecom recharge apps
# - Payment gateways
# - Hint
# - Use function for validation
# - Use while loop for retry

# %%
plans=[199, 299, 399, 599]

while True:
    amount=int(input())

    if amount<50:
        print("Min ₹50")
    elif amount in plans:
        print("Success")
        break
    else:
        print("Invalid plan")
# Out:
#  40
# Min ₹50
#  60
# Invalid plan
#  299
# Success

# %% [markdown]
# ## Problem 2: Inventory Reorder Alert System

# %% [markdown]
# - Problem Statement
# - Given a dictionary of products and stock quantities:
# - Print Reorder Alert if stock < 15
# - Print Stock OK otherwise
# - Real-Time Use
# - Warehouse systems
# - Retail management
# - Hint
# - Use function
# - Use for loop on dictionary

# %%
def check_stock(data):
    for item, quantity in data.items():
        if quantity<15:
            print(item,"-Recorder Alert")
        else:
            print(item,"-Stock OK")

products={"Rice":11,"Wheat":15,"Sugar":40}

check_stock(products)
# Out:
# Rice -Recorder Alert
# Wheat -Stock OK
# Sugar -Stock OK

# %% [markdown]
# ## Problem 3: Student Result Processing System

# %% [markdown]
# - Problem Statement
# - Create a function that:
# - Accepts a list of student marks
# - Calculates average marks
# - Prints Pass if average ≥ 50 else Fail
# - Real-Time Use
# - Online exam systems
# - Evaluation portals
# - Hint
# - Use loop to calculate total
# - Return result from function

# %%
def result(marks):
    total=0
    for i in marks:
        total+=i

    avg=total/len(marks)

    if avg>=50:
        return "Pass"
    else:
        return "Fail"

print(result([40,60,50]))
# Out:
# Pass

# %%
def result(marks):
    total=0
    for i in marks:
        total+=i

    avg=total/len(marks)

    if avg>=50:
        return "Pass"
    else:
        return "Fail"

print(result([20,25,30]))
# Out:
# Fail

# %% [markdown]
# ## Problem 4: Cab Fare Estimator with Retry Option

# %% [markdown]
# - Problem Statement
# - Create a cab fare calculator:
# - Base fare = ₹50
# - ₹12 per km
# - Peak hour → 25% extra
# - Allow retry using while loop
# - Real-Time Use
# - Ride-hailing apps
# - Transport systems
# - Hint
# - Function for fare calculation
# - While loop for retry

# %%
while True:
    try:
        km=float(input("Enter distance (km):"))
    except ValueError:
        print("Please enter a valid number")
        continue

    peak=input("Is is peak time?(y/n):")
    fare=50+km*12

    if peak=='y':
        fare*=1.25

    print("₹",fare)

    retry=input("Do you want to continue?(y/n):")
    if retry!='y':
        break
# Out:
# Enter distance (km): 4
# Is is peak time?(y/n): y
# ₹ 122.5
# Do you want to continue?(y/n): y
# Enter distance (km): 10
# Is is peak time?(y/n): n
# ₹ 170.0
# Do you want to continue?(y/n): n

# %% [markdown]
# ## Problem 5: Employee Attendance Eligibility Checker

# %% [markdown]
# - Problem Statement
# - Create a function that:
# - Accepts attendance list ("P", "A")
# - Calculates attendance percentage
# - Returns Eligible if ≥ 75% else Not Eligible
# - Real-Time Use
# - HR payroll systems
# - Internship tracking
# - Hint
# - Use loop to count present days
# - Use return statement

# %%
def check(data):
    p=0
    for i in data:
        if i=='P':
            p+=1

    if (p/len(data))*100>=75:
        return "Eligible"
    else:
        return "Not Eligible"

print(check(['P','A','P']))
# Out:
# Not Eligible

# %%
def check(data):
    p=0
    for i in data:
        if i=='P':
            p+=1

    if (p/len(data))*100>=75:
        return "Eligible"
    else:
        return "Not Eligible"

print(check(['P','P','P']))
# Out:
# Eligible

# %% [markdown]
# ## Problem 6: Password Strength Checker

# %% [markdown]
# - Problem Statement
# - Create a function to check password strength.
# - Rules:
# - Minimum length = 8
# - Must contain at least one digit
# - Must contain at least one special character (@#$)
# - Real-Time Use
# - Login systems
# - Security validation
# - Hint
# - Use loop over string
# - Use conditions inside function

# %%
def check(p):
    d=s=0
    for i in p:
        if i.isdigit():
            d=1

        if i in "@#$":
            s=1

    if len(p)>=8 and d and s:
        return "Strong"

    else:
        return "Weak"

print(check("abc@1234"))
# Out:
# Strong
